# %% [markdown]
# # IVIVE Dataset
#
# #### In this project, we attempt to wrangle data from the ChEMBL database for useful toxicokinetic values. We will demonstrate the labor and problemsolving involved in gathering, cleaning, and interpreting the data. Please note that there are a few associated files: two .csv datasets (which will be difficult to reproduce on your own, so I provided copies to load in here), and an R markdown file where some of the work was done.
#
#
# ### What is ChEMBL?
#
# #### ChEMBL is a manually curated database of bioactive molecules with drug inducing properties. It contains bioactivity data against drug targets; that is, millions of health-related measurements on some 2.5 million chemicals sourced from scientific papers.$^{1}$
#
# #### Specifically, we are interested in _clearance_ data, or how fast a chemical is metabolized by the human body. We typically measure this in units of dosage per time. In this case, our standard unit will be mL/kg/min, where the first volume is chemical dose and the kg mass is bodyweight (the drug target). We need to factor in that mass because we are drawing data from tests on different scales--for example, clearance through a liver tissue sample, or through a liver cell, and part our process will be scaling the values by dimensional analysis.
#
# #### This practice of comparing toxicokinetic data on different scales is called In Vitro-In Vivo Extrapolation (IVIVE), and it is an essential pillar of developing new methods for human-health risk assessment of chemicals, especially data-poor chemicals.$^{2}$
#
# #### One of the hurdles in pulling together data is that different fields use different names for compounds. This may not seem like a high-tech problem, but solving it is nontrivial. The chemical formula C$_{12}$H$_{4}$Cl$_{4}$O$_{2}$ describes at least 31 compounds with distinct properties. Each has been given a name by multiple international entities, such as IUPAC, SMILES, and InChi, and there is yet to be consensus across scientific fields as to which one is preferred. Only one of these compounds is 2,3,7,8-Tetrachlorodibenzodioxin, or simply Dioxin, the notorious Agent Orange contaminant.
#
# #### Luckily, ChEMBL developed its own API to query bioassays and related data without the need for advanced database skills.$^{3}$ We interface with it through the ChEMBL python client and retrieve bioassay data with the tags "clearance," "human liver microsome," and limited to human data.$^{4}$ Then, from those assays, we can query the associated chemicals, using their InchiKeys as ID. We unfortunately cannot just directly query the chemicals, and this complication ends up costing several hours of computing time.
#
# #### Finally, once we have InchiKeys matched with assay data, we can prepare the data for use by matching them with yet another identifier, DTXSID$^{5}$, as well as significant data cleaning.
#
#
#
# 1. https://www.ebi.ac.uk/chembl/
# 2. https://cfpub.epa.gov/si/si_public_record_Report.cfm?dirEntryId=355299&Lab=CCTE
# 3. https://github.com/chembl/chembl_webresource_client
# 4. Animal tests are still done, but the goal of IVIVE is to replace animal testing. As a future exploratory project, it would be interesting to compare animal test data with in-vitro data.
# 5. For example, see the DTXSID for Dioxin here: https://comptox.epa.gov/dashboard/chemical/details/DTXSID2021315

# %%
# Loading dependencies.
from chembl_webresource_client.new_client import new_client
from IPython.display import SVG
import pandas as pd
import csv
import time
import json
from chart_studio import plotly as plt
import plotly.express as px

available_resources = [resource for resource in dir(new_client) if not resource.startswith('_')]
print(available_resources)
# Out:
# ['activity', 'activity_supplementary_data_by_activity', 'assay', 'assay_class', 'atc_class', 'binding_site', 'biotherapeutic', 'cell_line', 'chembl_id_lookup', 'chembl_release', 'compound_record', 'compound_structural_alert', 'description', 'document', 'document_similarity', 'drug', 'drug_indication', 'drug_warning', 'go_slim', 'image', 'mechanism', 'metabolism', 'molecule', 'molecule_form', 'official', 'organism', 'protein_classification', 'similarity', 'source', 'substructure', 'target', 'target_component', 'target_relation', 'tissue', 'xref_source']

# %% [markdown]
# ### Querying ChEMBL for assays done on human proteins. For this case, we will search for particular terms "clearance" "human liver microsome" and "Homo sapiens":

# %%
clearance_assays1 = new_client.assay.filter(assay_organism = 'Homo sapiens', description__icontains = 'clearance')
clearance_assays2 = new_client.assay.filter(assay_organism = 'Homo sapiens', description__icontains = 'human liver microsome')

print( f"According to this query, there are {len(clearance_assays1)} assays with 'clearance' in description. \nAnd, {len(clearance_assays2)} assays with 'human liver microsome' in description."
     )
# Out:
# According to this query, there are 4858 assays with 'clearance' in description.
# And, 13110 assays with 'human liver microsome' in description.

# %% [markdown]
# ### These two queried subsets are likely not mutually exclusive, so we have to merge them in a set. One issue: the API returns them as QuerySet objects, which do not contain the chemical data themselves. We cannot perform set operations until we render them to DataFrame objects.
#
# NOTE: Converting QuerySet object to DataFrame using this method is painfully slow (about 1 min for 2542 rows):
#
# pd.DataFrame.from_records(QuerySet)
#
# This way seems to work faster:
#
# df = pd.DataFrame(
#     list(QuerySet), columns=["desired column", "another desired column"]
# )

# %%
start_time = time.time()
# --------------
chemblid1 = clearance_assays1.only(['clearance_assays_assay_chembl_id'])
chemblid2 = clearance_assays2.only(['clearance_assays_assay_chembl_id'])

df1 = pd.DataFrame(
    list(clearance_assays1), columns=["assay_chembl_id"]
)
df2 = pd.DataFrame(
    list(clearance_assays2), columns=["assay_chembl_id"]
)

assayIDs1 = df1["assay_chembl_id"].tolist()
assayIDs2 = df2["assay_chembl_id"].tolist()
assayIDs = list(set(assayIDs1 + assayIDs2))
# ------------------
print("There are", len(assayIDs), "assays.")
print("This took", time.time() - start_time, "to run.")
# Out:
# There are 15621 assays.
# This took 3.356687545776367 to run.

# %% [markdown]
# ### Then, for each of those assay's chembl_id, find the activity values. As query and not a Pandas operation, this doesn't take long.
#
# ##### Why not just skip the chembl_id step? Because you can't filter activity set by assay_description, for some reason.

# %%
# Filtering activities based on the assay_chembl_id, only those that we found to include the aforementioned keywords in the description, and on Homo sapiens
start_time = time.time()

activities = new_client.activity.filter( assay_chembl_id__in = assayIDs)

# ------------------
print("This took", time.time() - start_time, "to run.")
# Out:
# This took 0.005104541778564453 to run.

# %% [markdown]
# ## NOTE: This next part is the "long, difficult" part. You will not be able to reproduce this easily.
#
# #### The following chunks take several hours to complete. I *think* the API is not purpose built for retrieving data on this scale, so rendering out records on the scale of thousands leads to timeout errors. I would run this overnight to find that it gave me an error. So I split the dataset into multiple parts and ran queries piece by piece.

# %%
start_time = time.time()
def add_to_list(df, i):
    df.loc[len(df)] = (activities[i])

activities_df = pd.DataFrame(activities[0])

for i in range(len(activities)):
    add_to_list(activities_df, i)

activities_df = activities_df.loc[activities_df.astype(str).drop_duplicates().index]

print("This took", time.time() - start_time, "to run")
activities_df.to_csv("activities_values_to_filter_in_R_test.csv", index = False)
activities_df.head()
# Out:
# This took 28385.659880638123 to run
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33031                  []
# 1        None             None        34270                  []
# 2        None             None        34274                  []
# 3        None             None        34484                  []
# 4        None             None        35507                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL695026  In vitro oxidative metabolic stability measure...
# 1    CHEMBL695026  In vitro oxidative metabolic stability measure...
# 2    CHEMBL695026  In vitro oxidative metabolic stability measure...
# 3    CHEMBL708969  Rate of Oxidation in human liver microsomes is...
# 4    CHEMBL695026  In vitro oxidative metabolic stability measure...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# ...

# %% [markdown]
# With 78104 records, this takes 7.9 hours.

# %%
df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)
assay = len(df['molecule_chembl_id'].tolist())
chems = len(set(df['molecule_chembl_id'].tolist()))

print(f"There are {assay} assays for {chems} unique chemicals.")
# Out:
# There are 78104 assays for 47578 unique chemicals.

# %% [markdown]
# #### Next, searching for inchi key given the molecule_chembl_ids in the activities df.
#
# Iterate through all the Molecule IDs in df['molecule_chembl_id'], filter molecules to get the respective inchi_key
#
# Put it all together with list comprehension.

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[0:10000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df1 = df
df1.to_csv("activities_with_inchikeys_to_filter_in_R_p1.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 34.76613116264343 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[10000:20000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df2 = df
df2.to_csv("activities_with_inchikeys_to_filter_in_R_p2.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 3273.262047767639 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[20000:30000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df3 = df
df3.to_csv("activities_with_inchikeys_to_filter_in_R_p2.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 1706.0359268188477 to run

# %%
# this chunk gets a timeout error

import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[30000:40000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df4 = df
df4.to_csv("activities_with_inchikeys_to_filter_in_R_p3.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 85.80057764053345 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[40000:50000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df5 = df
df5.to_csv("activities_with_inchikeys_to_filter_in_R_p4.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 93.60196495056152 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[50000:60000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df6 = df
df6.to_csv("activities_with_inchikeys_to_filter_in_R_p5.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 87.48066544532776 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[60000:70000]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df7 = df
df7.to_csv("activities_with_inchikeys_to_filter_in_R_p6.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 79.25466585159302 to run

# %%
import numpy as np
import math

df = pd.read_csv('activities_values_to_filter_in_R.csv', index_col = False, low_memory=False)[70000:]

list_df = np.array_split(df, math.ceil(len(df)/1000))
# see for help: https://stackoverflow.com/questions/44729727/pandas-slice-large-dataframe-into-chunks

inchi_keys = []

start_time = time.time()
for i in list_df:
    for chembl_id in i['molecule_chembl_id'].tolist():
        try:
            inchi_keys += [new_client.molecule.filter(molecule_chembl_id = chembl_id)[0]["molecule_structures"]["standard_inchi_key"]]
        except TypeError:
            inchi_keys += ["NA"]
print("This took", time.time() - start_time, "to run")

df['standard_inchi_key'] = inchi_keys
df8 = df
df8.to_csv("activities_with_inchikeys_to_filter_in_R_p7.csv", index = False)

# running the chunk on the full df returns a TypeError:
# due to some chemicals, like df.loc[11669], CHEMBL1200457, which do not have an inchikey in chembl's database.
# Out:
# C:\Users\cgonza03\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# This took 66.02663087844849 to run

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8]
df = pd.concat(frames)
df.to_csv("activities_with_inchikeys_to_filter_in_R_all.csv", index = False)

# %% [markdown]
# ## At this point, there will be a gap in the Notebook, and we momentarily switch to R.
#
# #### The being that the packages to obtain DTXSIDs are only available for R, and not for python.
#
# #### Please see the .rmd file to see how we match our 78104 assay values to DTXSIDs, and then we will see you back here for some final analysis.

# %%
# So far, we have retrieved this many bioassay values relevant to our cause.
len(df)

# %%
df.loc['standard_inchi_key']
# Out:
#                                              action_type activity_comment  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 78099                                                NaN              NaN
# 78100                                                NaN              NaN
# 78101  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 78102                                                NaN              NaN
# 78103  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#        activity_id                                activity_properties  \
# ...

# %% [markdown]
# # Back to Python.

# %%
# For the scope of this project, this is the final dataset.
# There are just a few things to note: we filter the df to only those that include dtxsid. This leaves 9514 values.

raw = pd.read_csv('activities_with_dsstoxids.csv')
df = raw[raw['dtxsid'].notnull()]

print(
    f'Originally, we had {raw.shape} assays. After filtering to just values with dtxsids, we are left with {df.shape}. This is still a respectable amount of data.'
)
# Out:
# C:\Users\darnt\AppData\Local\Temp\ipykernel_10964\1028102883.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv('activities_with_dsstoxids.csv')
# Originally, we had (78104, 57) assays. After filtering to just values with dtxsids, we are left with (9514, 57). This is still a respectable amount of data.

# %%
# Let's take a glimpse.
df.head(5)
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 1276         NaN              NaN      1754435                  []
# 1280         NaN              NaN      1754455                  []
# 1363         NaN              NaN      1780698                  []
# 1364         NaN              NaN      1782086                  []
# 1365         NaN              NaN      1782087                  []
#
#      assay_chembl_id                                  assay_description  \
# 1276    CHEMBL853456  Intrinsic clearance in human hepatocytes per 1...
# 1280    CHEMBL853456  Intrinsic clearance in human hepatocytes per 1...
# 1363    CHEMBL910614                 Stability in human liver microsome
# 1364    CHEMBL910614                 Stability in human liver microsome
# 1365    CHEMBL910614                 Stability in human liver microsome
#
#      assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# ...

# %% [markdown]
# ### This dataset is treasure trove of bioassay interest, but not all of the rows and columns are relevant. For readability, we show a simplified chart with the only select columns displayed.
#
# #### Note that this would've been a much quicker process if the API allowed us to query based on bao-label.
#
# #### Our primary concerns are: standard_type, which briefly describes what the measurement was, standard_units, and stand_value, which will ultimately be used for the quantitative IVIVE assessments. We include canonical_smiles, standard_inchi_key, and dtxsid purely for interest, though we will not use them for calculations here.

# %%
df.loc[:,['assay_description','bao_label','canonical_smiles','standard_type','standard_units','standard_value','standard_inchi_key','dtxsid']].head(5)
# Out:
#                                       assay_description          bao_label  \
# 1276  Intrinsic clearance in human hepatocytes per 1...  cell-based format
# 1280  Intrinsic clearance in human hepatocytes per 1...  cell-based format
# 1363                 Stability in human liver microsome   microsome format
# 1364                 Stability in human liver microsome   microsome format
# 1365                 Stability in human liver microsome   microsome format
#
#                                       canonical_smiles standard_type  \
# 1276    Cc1ccc2c(c1)c(-c1ccnc3c(C)cccc13)c(C)n2CC(=O)O            CL
# 1280  COc1ccc2c(c1)c(CC(=O)O)c(C)n2-c1ccnc2cc(Cl)ccc12            CL
# 1363                              NCc1ccc(-c2cccnc2)s1          T1/2
# 1364                              NCc1cc(-c2cccnc2)no1          T1/2
# 1365                           NCc1cc(-c2cccnc2)n[nH]1          T1/2
#
#               standard_units  standard_value           standard_inchi_key  \
# ...

# %% [markdown]
# #### The easiest way to make sure we have the data we need is by checking the units. There are a huge variety of units, despite the label "standard_units."
#
# #### Upon closer inspection, we notice there are several records that do not fit our needs. Some are values of mass, time, moles, and so on which are not usable. Depending on the situation, it is not always pragmatic to pore over every single anomolous data point, and here we will exclude them.

# %%
df.standard_units.unique()
# Out:
# array(['uL.min-1.(10^6cells)-1', 'hr', '%', 'pmol/mg', 'nM',
#        'mL.min-1.g-1', 'L/hr', 'ml/min', 'min/ml/hr', nan, 'pmol/min/mg',
#        'uL/min', 'mL.min-1.kg-1', 'nmol/mg/min', 'ml/min/mg', 'ml/min.kg',
#        'nM/min/mg', 'hr.Kg/L', 'microL/min/mg', 'uL/ml/kg', 'mg/ml/g',
#        'pmol/hr', 'l/h', 'ug.hr/ml', 'pmol/min', 'uL/ml.millig', 'uM',
#        'ml/hr', 'nmol/min/mg', 'L/min', 'ng.hr.mL-1', 'l', 'mg', '/hr',
#        'min-1', '/min/nM', 'uL/min.mg', '/min', 'pmol', 'ng/ml', 'min/mL',
#        'min', 'uM/min.mg', 'ml/min.Kg', "10'-4/min", 'ug/min', 'L.h-1',
#        'L.h-1.m-2', 'uL/min/nmol', 'pl/min', 'nmol/min', 'pmol/min/ug',
#        'nl/min', 'pmol/mg.min', 'uL/mg/min', 'pmol/mg/min', 'ml/min/nmol',
#        'pmol/min/g', 'L/Kg', 'min/ml/kg', 'L/Kg.hr', 'uL/min/pmol',
#        'L/hr/m2', 'ml/min.g', '/M/min', 'l/min/mg', 'mL.min/g',
#        'nL/pmol/min', 'uM.hr'], dtype=object)

# %%
fig = px.histogram(df, x="standard_units")
fig.show()

# %%
# Getting rid of some entries where units strongly indicate that the value is not relevant.

df2 = df[~df["standard_units"].isin(['hr','%','pmol/mg','nM','L/hr','uL/min','l/h', 'uM', 'ml/min', 'min/ml/hr', 'nan', 'L/Kg', 'l', 'mg', '/hr',"10'-4/min", 'ug/min', 'L.h-1'])]

fig = px.histogram(df2, x="standard_units")
fig.show()

# %% [markdown]
# #### There are still several edge cases where the units are not lined up with our standard of mL/kg/min. But for the purposes of this demonstration, there is one group of low-hanging fruit. Some 1000 assays have units mL.min-1.g-1, which can easily be converted to our standard through dimensional analysis.
#
# #### Below, we convert the units and accordingly scale the values in the "standard_value" column. As proof, you can see that the column for "mL/kg/min" increases by about 1000. We have a total of 3755 values so far.

# %%
mask = df2["standard_units"] == "mL.min-1.g-1"
df3=df2
df3.loc[mask, "standard_value"] = df3.loc[mask, "standard_value"] * 1000
df3.loc[mask, "standard_units"] = "mL.min-1.kg-1"

fig = px.histogram(df3, x="standard_units")
fig.show()

# %% [markdown]
# #### Finally, we can see how many different chemicals this represents. We have narrowed the query down to 1332 unique dtxsid, meaning some of the assays represent repeated trials.
#
# #### For the sake of exploration, we also observe the chemicals that received the most repeated trials. The mode is DTXSID6022923, also known as Diclofenac, at 104 recorded assays. This is not suprising given that the chemical is used as a pain killer.

# %%
len(
    df3.loc[df3["standard_units"] == "mL.min-1.kg-1"].dtxsid.unique()
)
# Out:
# 1332

# %%
fig = px.histogram(df3, x="dtxsid")
fig.show()

# %% [markdown]
# ## Further work would be needed to clean and prepare this dataset for use in IVIVE, but we have demonstrated the bulk of the data skills involved.
